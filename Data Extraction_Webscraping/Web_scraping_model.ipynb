# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re
from time import sleep
from random import randint


headers = {"Accept-Language": "en-US, en;q=0.5"}

state=pd.read_csv("State.csv")
make =pd.read_csv("Make.csv")

for h in range(0,62):
    print(make['Make'][h])

    html_p = requests.get("https://www.dealerrater.com/directory/"+str(state['State'][43])+"/"+str(make['Make'][h])+"/")
    soup = BeautifulSoup(html_p.text,"html.parser")

    a = soup.h2.text
    a=a.replace(",","")
    print(a)

    numbers = [int(word) for word in a.split() if word.isdigit()]
    #print(numbers)
    if(len(numbers)!=0):


        print("Number of Dealers=",numbers[0])
        num=numbers[0]



        if num!=0:


            if (num%30)!=0:
                pgn=(int(num/30)+1)
            else:
                pgn=int(num/30)


        links=[]
        new_links=[]
        review_links=[]



        for z in range(1,pgn+1):


            html_page = requests.get("https://www.dealerrater.com/directory/"+str(state['State'][43])+"/"+str(make['Make'][h])+"/page"+str(z)+"/")
            soup = BeautifulSoup(html_page.text,"html.parser")

            for link in soup.find_all('a'):
                links.append(link.get('href'))
            for i in links:
                s = str(i)
                if s.find('/dealer/') != -1 and s.find('#r')==-1:
                    new_links.append(i)






            l = np.array(new_links)
            k =np.unique(l)
            d=k.tolist()
            print(d)






        for i in d:



            page = requests.get("https://www.dealerrater.com"+str(i)+"?filter=ALL_REVIEWS#link")
            new_soup = BeautifulSoup(page.text, "html.parser")

            c = new_soup.h2.text
            c=c.replace("'", "")

            if c.find("Showing")!=-1:
                c=c.replace("\n", "")
                c=c.replace("\r", "")


            #print(c)
            c=c.replace(",","")
            number = [int(word) for word in c.split() if word.isdigit()]
            #print(number)
            if(len(number)!=0):

                if (number[0]%10)!=0:

                    pg=(int(number[0]/10)+1)
                else:

                    pg=(int(number[0]/10))
                print("Number of pages in this dealer=",pg)

                if (number[0]>1):

                    pages = np.arange(1,pg+1)
                    print(pages)

                    headers = {"Accept-Language": "en-US, en;q=0.5"}


                    ratings = []

                    review = []

                    date=[]


                    x=1
                    for v in pages:

                    #print(x)
                        x+=1
                        page = requests.get("https://www.dealerrater.com"+str(i)+"page"+str(v)+"/?filter=ALL_REVIEWS#link", headers=headers)
                        print(str(v))
                        soup = BeautifulSoup(page.text, "html.parser")

                        review_section = soup.find_all('div',class_="col-xs-12 col-sm-9 pad-none review-wrapper")
                        details_section = soup.find_all('div',class_="col-xs-12 col-sm-3 pad-left-none text-center review-date margin-bottom-md")
                        #sleep(2)
                        for container in review_section:

                            name = container.p.text

                            review.append(name)

                        for container in details_section:
                            name = container.div.text

                            date.append(name)

                            if container.find('div',class_="rating-static hidden-xs rating-0 margin-center"): ratings.append(0.0)
                            if container.find('div',class_="rating-static hidden-xs rating-1 margin-center"): ratings.append(0.1)
                            if container.find('div',class_="rating-static hidden-xs rating-2 margin-center"): ratings.append(0.2)
                            if container.find('div',class_="rating-static hidden-xs rating-3 margin-center"): ratings.append(0.3)
                            if container.find('div',class_="rating-static hidden-xs rating-4 margin-center"): ratings.append(0.4)
                            if container.find('div',class_="rating-static hidden-xs rating-5 margin-center"): ratings.append(0.5)
                            if container.find('div',class_="rating-static hidden-xs rating-6 margin-center"): ratings.append(0.6)
                            if container.find('div',class_="rating-static hidden-xs rating-7 margin-center"): ratings.append(0.7)
                            if container.find('div',class_="rating-static hidden-xs rating-8 margin-center"): ratings.append(0.8)
                            if container.find('div',class_="rating-static hidden-xs rating-9 margin-center"): ratings.append(0.9)
                            if container.find('div',class_="rating-static hidden-xs rating-10 margin-center"): ratings.append(1.0)
                            if container.find('div',class_="rating-static hidden-xs rating-11 margin-center"): ratings.append(1.1)
                            if container.find('div',class_="rating-static hidden-xs rating-12 margin-center"): ratings.append(1.2)
                            if container.find('div',class_="rating-static hidden-xs rating-13 margin-center"): ratings.append(1.3)
                            if container.find('div',class_="rating-static hidden-xs rating-14 margin-center"): ratings.append(1.4)
                            if container.find('div',class_="rating-static hidden-xs rating-15 margin-center"): ratings.append(1.5)
                            if container.find('div',class_="rating-static hidden-xs rating-16 margin-center"): ratings.append(1.6)
                            if container.find('div',class_="rating-static hidden-xs rating-17 margin-center"): ratings.append(1.7)
                            if container.find('div',class_="rating-static hidden-xs rating-18 margin-center"): ratings.append(1.8)
                            if container.find('div',class_="rating-static hidden-xs rating-19 margin-center"): ratings.append(1.9)
                            if container.find('div',class_="rating-static hidden-xs rating-20 margin-center"): ratings.append(2.0)
                            if container.find('div',class_="rating-static hidden-xs rating-21 margin-center"): ratings.append(2.1)
                            if container.find('div',class_="rating-static hidden-xs rating-22 margin-center"): ratings.append(2.2)
                            if container.find('div',class_="rating-static hidden-xs rating-23 margin-center"): ratings.append(2.3)
                            if container.find('div',class_="rating-static hidden-xs rating-24 margin-center"): ratings.append(2.4)
                            if container.find('div',class_="rating-static hidden-xs rating-25 margin-center"): ratings.append(2.5)
                            if container.find('div',class_="rating-static hidden-xs rating-26 margin-center"): ratings.append(2.6)
                            if container.find('div',class_="rating-static hidden-xs rating-27 margin-center"): ratings.append(2.7)
                            if container.find('div',class_="rating-static hidden-xs rating-28 margin-center"): ratings.append(2.8)
                            if container.find('div',class_="rating-static hidden-xs rating-29 margin-center"): ratings.append(2.9)
                            if container.find('div',class_="rating-static hidden-xs rating-30 margin-center"): ratings.append(3.0)
                            if container.find('div',class_="rating-static hidden-xs rating-31 margin-center"): ratings.append(3.1)
                            if container.find('div',class_="rating-static hidden-xs rating-32 margin-center"): ratings.append(3.2)
                            if container.find('div',class_="rating-static hidden-xs rating-33 margin-center"): ratings.append(3.3)
                            if container.find('div',class_="rating-static hidden-xs rating-34 margin-center"): ratings.append(3.4)
                            if container.find('div',class_="rating-static hidden-xs rating-35 margin-center"): ratings.append(3.5)
                            if container.find('div',class_="rating-static hidden-xs rating-36 margin-center"): ratings.append(3.6)
                            if container.find('div',class_="rating-static hidden-xs rating-37 margin-center"): ratings.append(3.7)
                            if container.find('div',class_="rating-static hidden-xs rating-38 margin-center"): ratings.append(3.8)
                            if container.find('div',class_="rating-static hidden-xs rating-39 margin-center"): ratings.append(3.9)
                            if container.find('div',class_="rating-static hidden-xs rating-40 margin-center"): ratings.append(4.0)
                            if container.find('div',class_="rating-static hidden-xs rating-41 margin-center"): ratings.append(4.1)
                            if container.find('div',class_="rating-static hidden-xs rating-42 margin-center"): ratings.append(4.2)
                            if container.find('div',class_="rating-static hidden-xs rating-43 margin-center"): ratings.append(4.3)
                            if container.find('div',class_="rating-static hidden-xs rating-44 margin-center"): ratings.append(4.4)
                            if container.find('div',class_="rating-static hidden-xs rating-45 margin-center"): ratings.append(4.5)
                            if container.find('div',class_="rating-static hidden-xs rating-46 margin-center"): ratings.append(4.6)
                            if container.find('div',class_="rating-static hidden-xs rating-47 margin-center"): ratings.append(4.7)
                            if container.find('div',class_="rating-static hidden-xs rating-48 margin-center"): ratings.append(4.8)
                            if container.find('div',class_="rating-static hidden-xs rating-49 margin-center"): ratings.append(4.9)
                            if container.find('div',class_="rating-static hidden-xs rating-50 margin-center"): ratings.append(5.0)


                    df=pd.DataFrame(zip(date,review,ratings),columns =['Date','Reviews', 'Ratings'])
                    #print(df)

                    name_file=(str(make['Make'][h])+str(c)+".csv")
                    name_file=name_file.replace("'", "")
                    name_file=name_file.replace("/", "")

                    if name_file.find("Showing")!=-1:
                        name_file=str(number[0])+".csv"



                    df.to_csv(name_file)



            #sleep(5)
            #files.download(name_file)
                    print("Completed")

                if(number[0]<1):
                    print("Number of reviews less than 1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-97b7160efd7a> in <cell line: 12>()
#      10 headers = {"Accept-Language": "en-US, en;q=0.5"}
#      11
# ---> 12 state=pd.read_csv("State.csv")
#      13 make =pd.read_csv("Make.csv")
#      14
#
# ...
